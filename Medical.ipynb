# %% [markdown]
# <a href="https://colab.research.google.com/github/Jmochabo11617/Data--A/blob/main/Medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading a Medical dataset from google drive
#
# *  The data been loaded is a Medical dataset that was downloaded online.

# %%
from google. colab import drive
drive. mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing necessary libraries
#
# *   pandas
# *   numpy
# *  seaborn
# *   matplotlib

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/Medical.csv')

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
df.shape
# Out:
# (1319, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %% [markdown]
# EDA and Visualization of the Dataset
#
# 1.Here we transform the data to a suitable form for specific analysis.
# 2.This done by summarizing the data, creating new variables and standardizing the data.

# %%
df.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %% [markdown]
# Data visualization
#
# Here we have various graphs like Boxplot, countplot, pairplot and  Histogram. All these show the distribution and correlation of different variables that helps us to understand the each of the variable.

# %%
plt.figure(figsize=(25, 15))
sns.countplot(data = df, x = 'Age', hue = 'Gender')
plt.show()

# %%
df.boxplot(figsize=(15,10))
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.hist(df['Age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df.dtypes
# Out:
# Age                           int64
# Gender                        int64
# Heart rate                    int64
# Systolic blood pressure       int64
# Diastolic blood pressure      int64
# Blood sugar                 float64
# CK-MB                       float64
# Troponin                    float64
# Result                       object
# dtype: object

# %%
df = pd.get_dummies(df, columns=['Result'])

# %%
df.replace({'Positive':1, 'Negative':0}, inplace=True)

# %%
df.dtypes
# Out:
# Age                           int64
# Gender                        int64
# Heart rate                    int64
# Systolic blood pressure       int64
# Diastolic blood pressure      int64
# Blood sugar                 float64
# CK-MB                       float64
# Troponin                    float64
# Result_negative                bool
# Result_positive                bool
# dtype: object

# %%
print(df.shape)
# Out:
# (1319, 10)

# %%
df.Troponin.unique()
# Out:
# array([1.20e-02, 1.06e+00, 3.00e-03, 1.22e-01, 4.00e-03, 2.37e+00,
#        1.10e-02, 6.00e-03, 1.30e-02, 5.37e+00, 1.70e-02, 7.76e-01,
#        2.00e-02, 5.00e-03, 4.91e-01, 6.12e-01, 1.39e+00, 7.00e-03,
#        1.00e+01, 8.30e+00, 2.10e-02, 1.15e+00, 1.46e-01, 8.00e-03,
#        2.60e-02, 5.30e-02, 9.00e-03, 6.70e-02, 4.00e-02, 1.00e-02,
#        3.10e-02, 1.50e-02, 7.60e-02, 5.20e-02, 1.01e+00, 8.90e-02,
#        2.80e-02, 7.03e-01, 8.50e-02, 2.19e-01, 8.64e-01, 1.05e-01,
#        4.80e-02, 8.88e-01, 1.60e-02, 1.07e+00, 2.20e-02, 6.05e+00,
#        7.10e-02, 1.03e-01, 2.30e-02, 3.80e-02, 5.10e-02, 2.90e-02,
#        1.40e-02, 2.23e+00, 1.55e+00, 1.84e+00, 6.40e-01, 7.67e+00,
#        6.10e-02, 9.40e-02, 2.70e-02, 5.40e-02, 2.52e-01, 1.79e+00,
#        1.95e+00, 3.92e-01, 3.27e-01, 4.60e-02, 1.24e+00, 1.78e-01,
#        1.90e-02, 1.97e+00, 6.81e-01, 1.06e-01, 1.46e+00, 6.30e-02,
#        1.23e+00, 2.86e+00, 1.64e-01, 1.86e+00, 3.20e-02, 2.40e-02,
# ...

# %%
pd.crosstab(index=df['Result_positive'], columns=df['Age'])
# Out:
# Age              14   19   20   21   22   23   24   25   26   27   ...  83   \
# Result_positive                                                    ...
# False              1    1    1    2    3    1    2    3    2    3  ...    1
# True               0    2    1    3    0    1    0    1    1    3  ...    1
#
# Age              84   85   86   87   88   90   91   100  103
# Result_positive
# False              0    1    1    0    0    1    1    0    0
# True               1    4    4    2    1    2    0    1    2
#
# [2 rows x 75 columns]

# %%
df.Result_positive.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Result_positive'>

# %% [markdown]
# Modeling of the data
#
# These odels helps to identify patterns, relationships, and insights within the data.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
x = df.drop(['Troponin'], axis=1)
y = df['Troponin']

# %% [markdown]
# Split the Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_df = x_train.join(y_train)
train_df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 52     63       0          81                      130
# 426    21       1          85                      138
# 918    27       1          98                       91
# 1093   29       1          76                      157
# 402    66       1          80                      154
# ...   ...     ...         ...                      ...
# 169    46       1          78                      150
# 809    50       1          82                      120
# 1032   54       1          83                      153
# 245    59       1          60                       86
# 28     47       0          66                      134
#
#       Diastolic blood pressure  Blood sugar   CK-MB  Result_negative  \
# 52                          65         98.0    2.28            False
# 426                         98        257.0    9.90            False
# 918                         50        147.0    1.20             True
# ...

# %%
train_df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Heart rate'}>],
#        [<Axes: title={'center': 'Systolic blood pressure'}>,
#         <Axes: title={'center': 'Diastolic blood pressure'}>,
#         <Axes: title={'center': 'Blood sugar'}>],
#        [<Axes: title={'center': 'CK-MB'}>,
#         <Axes: title={'center': 'Troponin'}>, <Axes: >]], dtype=object)

# %%
 plt.figure(figsize=(15,10))
sns.heatmap(train_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(train_df, hue='Troponin')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=train_df, x='Age', y='Troponin', hue='Result_negative', palette='coolwarm' )
# Out:
# <Axes: xlabel='Age', ylabel='Troponin'>

# %%
x_train, y_train = train_df.drop(['Troponin'], axis=1 ), train_df['Troponin']
reg= LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train, y_train)
# Out:
# 0.0667075858714814

# %%
scaler = StandardScaler()

# %%
x_train_s = scaler.fit_transform(x_train)

# %%
reg.score(x_train_s, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -0.6055899207673332

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_test, y_test)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.8386209179681259
